# %% [markdown]
# Ceci est un document Jupyter Notebook, dans ce type de document, on peut mêler du texte et du code Python directement exécutable. Dans un premier temps, il va nous falloir importer nos données depuis les fichiers .txt qui sont dans le dossier data du repository.
